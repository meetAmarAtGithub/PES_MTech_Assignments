# %% [markdown]
#  <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Tangerine">
# <div style="font-family: 'Tangerine', serif; text-align:center; font-size: 35px; text-shadow: 4px 4px 4px #aaa;">A Visual Exploration and Statitical Anlysis of Diabetes Dataset</div>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <br/>
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 35px;text-align:center;"><br/>Overview (Project statement)
#
#
# 1.Overview (Project statement)
#
# 2.Data Description
#
# 3.Data exploration and Analysis
#
# 4.Visualizations using Python libraries
#
# 5.Conclusion
# </div>
# <br/>

# %%
Exploratory data analysis using Seaborn and Matplotlib.

# %%
Github - we have hosted dataset and the Jupyter program in Github to enable collaborative working with in the team.

# %%
#importig libraries for analyzing our data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %% [markdown]
# ## Loading data and viewing first five rows

# %%
# dataset is hosted at Github following path - https://raw.githubusercontent.com/meetAmarAtGithub/PES_MTech_Assignments/master/NPV_Statitical%20Anlysis%20of%20Diabetes%20Dataset/diabetes.csv
df1 = pd.read_csv('https://raw.githubusercontent.com/meetAmarAtGithub/PES_MTech_Assignments/master/NPV_Statitical%20Anlysis%20of%20Diabetes%20Dataset/diabetes.csv')
df1.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  768 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          768 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            768 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            768 non-null    float64
#  6   Diabetes pedigree function                                                768 non-null    float64
#  7   Age (years)                                                               768 non-null    int64
#  8   Class variable                                                            768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# The dataset contains following columns. We have total 768 rows -
# * **Number of times pregnant**
# * **Plasma glucose concentration over 2 hours in an oral glucose tolerance test**
# * **Diastolic blood pressure (mm Hg)**
# * **Triceps skin fold thickness (mm)**
# * **2-Hour serum insulin (mu U/ml)**
# * **Body mass index (weight in kg/(height in m)2)**
# * **Diabetes pedigree function** - a function which scores probability of geting diabetes based on family history
# * **Age (years)**
# * **Class variable** -0 if non-diabetic, 1 if diabetic

# %% [markdown]
# ### Check for NAN in DataFrame

# %%
df1.isna().sum()
# Out:
# Number of times pregnant                                                    0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    0
# Diastolic blood pressure (mm Hg)                                            0
# Triceps skin fold thickness (mm)                                            0
# 2-Hour serum insulin (mu U/ml)                                              0
# Body mass index (weight in kg/(height in m)^2)                              0
# Diabetes pedigree function                                                  0
# Age (years)                                                                 0
# Class variable                                                              0
# dtype: int64

# %% [raw]
# There is no NaN in dataframe.

# %% [markdown]
# <p style="color:red; text-align:center; font-size: 22px"> Amar work <br/>
# 1.Need to change column names<br/>
# 2. Replace 0 and 1 in Class variable with Diabetic and Non-Diabetic<br/>
# </p>

# %%
#*********we need high light rows with colour where min. value is zero
df1.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000

# %% [markdown]
# ### Checking for count of zeroes for each column

# %%
#This is to find how many column wise zero(0) rows are there!
print(df1.isin([0]).sum())
# Out:
# Number of times pregnant                                                    111
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test      5
# Diastolic blood pressure (mm Hg)                                             35
# Triceps skin fold thickness (mm)                                            227
# 2-Hour serum insulin (mu U/ml)                                              374
# Body mass index (weight in kg/(height in m)^2)                               11
# Diabetes pedigree function                                                    0
# Age (years)                                                                   0
# Class variable                                                              500
# dtype: int64

# %%
##we need to find Mean / Median and replace all zeroes with that using Box plot analysis
#df2=df1[(df1.T != 0).any()]
df2 = df1[df1['2-Hour serum insulin (mu U/ml)'] > 0]
#df2.info()
df2[['2-Hour serum insulin (mu U/ml)']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
##we need to find Mean / Median and replace all zeroes with that using Box plot analysis
#df2=df1[(df1.T != 0).any()]
df3 = df1[df1['Triceps skin fold thickness (mm)'] > 0]
#df2.info()
df3[['Triceps skin fold thickness (mm)']].plot(kind='box')
df3.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         27.334635
# std                           19.355807                          9.229014
# min                            0.000000                          7.000000
# 25%                           62.000000                         23.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000

# %%
df1 =df1[df1['Plasma glucose concentration a 2 hours in an oral glucose tolerance test'] > 0]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  763 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  763 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          763 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          763 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            763 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            763 non-null    float64
#  6   Diabetes pedigree function                                                763 non-null    float64
#  7   Age (years)                                                               763 non-null    int64
#  8   Class variable                                                            763 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 59.6 KB

# %%
df1 =df1[df1['Diastolic blood pressure (mm Hg)'] > 0]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 728 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  728 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  728 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          728 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          728 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            728 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            728 non-null    float64
#  6   Diabetes pedigree function                                                728 non-null    float64
#  7   Age (years)                                                               728 non-null    int64
#  8   Class variable                                                            728 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 56.9 KB

# %%
df1 =df1[df1['Body mass index (weight in kg/(height in m)^2)'] > 0]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 724 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  724 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  724 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          724 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          724 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            724 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            724 non-null    float64
#  6   Diabetes pedigree function                                                724 non-null    float64
#  7   Age (years)                                                               724 non-null    int64
#  8   Class variable                                                            724 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 56.6 KB

# %%
#Find median of Triceps skin fold thickness (mm) and replace it in the Data Frame
#pending work will be removing outlayers from the calculatin of median
tricepsMean = df1['Triceps skin fold thickness (mm)'].median()
print(tricepsMean)
df1['Triceps skin fold thickness (mm)'] = df1['Triceps skin fold thickness (mm)'].replace(0, tricepsMean)

df1[df1['Triceps skin fold thickness (mm)'] == 0]
# Out:
# 24.0
# Empty DataFrame
# Columns: [Number of times pregnant, Plasma glucose concentration a 2 hours in an oral glucose tolerance test, Diastolic blood pressure (mm Hg), Triceps skin fold thickness (mm), 2-Hour serum insulin (mu U/ml), Body mass index (weight in kg/(height in m)^2), Diabetes pedigree function, Age (years), Class variable]
# Index: []

# %%
#Find median of Triceps skin fold thickness (mm) and replace it in the Data Frame
#pending work will be removing outlayers from the calculatin of median
tricepsMean = df1['2-Hour serum insulin (mu U/ml)'].median()
print(tricepsMean)
df1['2-Hour serum insulin (mu U/ml)'] = df1['2-Hour serum insulin (mu U/ml)'].replace(0, tricepsMean)

df1[df1['2-Hour serum insulin (mu U/ml)'] == 0]
# Out:
# 48.0
# Empty DataFrame
# Columns: [Number of times pregnant, Plasma glucose concentration a 2 hours in an oral glucose tolerance test, Diastolic blood pressure (mm Hg), Triceps skin fold thickness (mm), 2-Hour serum insulin (mu U/ml), Body mass index (weight in kg/(height in m)^2), Diabetes pedigree function, Age (years), Class variable]
# Index: []

# %% [markdown]
# ## Data Exploration

# %%
##2-Hour serum insulin (mu U/ml) has large number of missing values , so we are going to drop this column
#below axis=1 signifis we need to drop the column
#df1.drop('2-Hour serum insulin (mu U/ml)',axis=1)

# %%
df1.groupby('Class variable').mean()
#df2[['disp','hp']].plot(kind='box')
# Out:
#                 Number of times pregnant  \
# Class variable
# 0                               3.320000
# 1                               4.907631
#
#                 Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# Class variable
# 0                                                      111.016842
# 1                                                      142.610442
#
#                 Diastolic blood pressure (mm Hg)  \
# Class variable
# 0                                      70.907368
# 1                                      75.248996
#
#                 Triceps skin fold thickness (mm)  \
# Class variable
# 0                                      26.458947
# 1                                      30.381526
#
#                 2-Hour serum insulin (mu U/ml)  \
# Class variable
# 0                                    72.176842
# 1                                   107.991968
#
#                 Body mass index (weight in kg/(height in m)^2)  \
# Class variable
# 0                                                    30.974947
# 1                                                    35.313655
#
#                 Diabetes pedigree function  Age (years)
# Class variable
# 0                                 0.430297    31.258947
# 1                                 0.559594    37.341365

# %%
df3 = df1[df1['Triceps skin fold thickness (mm)'] > 0 ,['Class variable'] =0]]
df3[['Triceps skin fold thickness (mm)']].plot(kind='box')

# %%
Groups=df1.columns
Mgroups=[]
Fgroups=[]

Mgroups = df1[df1['Class variable'] == 1]

Fgroups=df1[df1['Class variable'] == 0]

sns.boxplot(x = Mgroups,
            y = Fgroups,
            hue = df1['Class variable'])

# %%
df1.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %% [markdown]
# <p style="color:red; text-align:center; font-size: 22px"> <br/>
#     ********************  Amar work to start  *****************<br/>
# </p>

# %%
sns.boxplot(y=[ ['Number of times pregnant',
       'Plasma glucose concentration a 2 hours in an oral glucose tolerance test'] ], x='Class variable', 
                 data=df1, 
                 palette="colorblind",
           hue=df1['Class variable'])

# %%
Groups = df1.columns
for g in Groups:
    if g == 'Class variable':
        continue        
    dfgc = df1[g]
    if dfgc[dfgc['Class variable'] == 0]:
        m=dfgc[g]
    else:
        f=dfgc[g]        
    Mgroups.append(m.tolist())
    Fgroups.append(f.tolist())

# %%
df1 = df1.astype(float)
Groups = df1.columns
Groups=df1.columns
Mgroups=[]
Fgroups=[]

Mgroups = df1[df1['Class variable'] == 1].astype(float)

Fgroups=df1[df1['Class variable'] == 0].astype(float)

fig=plt.figure()
ax = plt.axes()
def setBoxColors(bp,cl):
    plt.setp(bp['boxes'], color=cl, linewidth=2.)
    plt.setp(bp['whiskers'], color=cl, linewidth=2.5)
    plt.setp(bp['caps'], color=cl,linewidth=2)
    plt.setp(bp['medians'], color=cl, linewidth=3.5)

bpl = plt.boxplot(Mgroups, positions=np.array(range(len(Mgroups)))*3.0-0.4,vert=False,whis='range', sym='', widths=0.6)
bpr = plt.boxplot(Fgroups, positions=np.array(range(len(Fgroups)))*3.0+0.4,vert=False,whis='range', sym='', widths=0.6)
setBoxColors(bpr, '#D7191C') 
setBoxColors(bpl, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='0')
plt.plot([], c='#2C7BB6', label='1')
plt.legend()

plt.yticks(range(0, len(Groups) * 3, 3), Groups)
plt.ylim(-3, len(Groups)*3)
#plt.xlim(0, 8)
plt.show()
# Out:
# <ipython-input-98-e91cef46851a>:19: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   bpl = plt.boxplot(Mgroups, positions=np.array(range(len(Mgroups)))*3.0-0.4,vert=False,whis='range', sym='', widths=0.6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-e91cef46851a> in <module>
#      17     plt.setp(bp['medians'], color=cl, linewidth=3.5)
#      18
# ---> 19 bpl = plt.boxplot(Mgroups, positions=np.array(range(len(Mgroups)))*3.0-0.4,vert=False,whis='range', sym='', widths=0.6)
#      20 bpr = plt.boxplot(Fgroups, positions=np.array(range(len(Fgroups)))*3.0+0.4,vert=False,whis='range', sym='', widths=0.6)
#      21 setBoxColors(bpr, '#D7191C')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2515         whiskerprops=None, manage_ticks=True, autorange=False,
#    2516         zorder=None, *, data=None):
# -> 2517     return gca().boxplot(
#    2518         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2519         positions=positions, widths=widths, patch_artist=patch_artist,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3777                                 stats['cihi'] = ci[1]
#    3778
# -> 3779         artists = self.bxp(bxpstats, positions=positions, widths=widths,
#    3780                            vert=vert, patch_artist=patch_artist,
#    3781                            shownotches=notch, showmeans=showmeans,
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#    4026             positions = list(range(1, N + 1))
#    4027         elif len(positions) != N:
# -> 4028             raise ValueError(datashape_message.format("positions"))
#    4029
#    4030         positions = np.array(positions)
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
s = df1[df1['Class variable'] == 1].astype(float)
t = df1[df1['Class variable'] == 0].astype(float)
df = pd.DataFrame({'Group':[0,1],'M':s,'F':t})
print(df)
df = df[['Group','M','F']]

Groups=df1.columns
Columns=df.columns.tolist()[1:]
print (Columns)
Mgroups=[]
Fgroups=[]

for g in Groups:
    dfgc = df[df['Group']==g]
    m=dfgc['M'].dropna()
    f=dfgc['F'].dropna()
    Mgroups.append(m.tolist())
    Fgroups.append(f.tolist())

fig=plt.figure()
ax = plt.axes()
def setBoxColors(bp,cl):
    plt.setp(bp['boxes'], color=cl, linewidth=2.)
    plt.setp(bp['whiskers'], color=cl, linewidth=2.5)
    plt.setp(bp['caps'], color=cl,linewidth=2)
    plt.setp(bp['medians'], color=cl, linewidth=3.5)

bpl = plt.boxplot(Mgroups, positions=np.array(range(len(Mgroups)))*3.0-0.4,vert=False,whis='range', sym='', widths=0.6)
bpr = plt.boxplot(Fgroups, positions=np.array(range(len(Fgroups)))*3.0+0.4,vert=False,whis='range', sym='', widths=0.6)
setBoxColors(bpr, '#D7191C') # colors are from http://colorbrewer2.org/
setBoxColors(bpl, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='F')
plt.plot([], c='#2C7BB6', label='M')
plt.legend()

plt.yticks(range(0, len(Groups) * 3, 3), Groups)
plt.ylim(-3, len(Groups)*3)
#plt.xlim(0, 8)
plt.show()

# %%
x =np.random.rand(10)
print(type(x))
print(x)
# Out:
# <class 'numpy.ndarray'>
# [0.76749553 0.26247549 0.99240982 0.59867258 0.71358133 0.79699687
#  0.63777281 0.56611206 0.43365625 0.72655164]

# %% [markdown]
# <p style="color:red; text-align:center; font-size: 22px"> <br/>
#     ******************** Amar work to end  *****************<br/>
# </p>

# %% [markdown]
# ## Histograms

# %% [markdown]
# In the Histogram below we are visualizing total sample data in terms of absolute count.

# %%
for i,col in enumerate(df1.columns[:-1]):
    plt.figure(i)
    sns.displot(df1[col], kind='hist', rug=True);

# %% [markdown]
# ## Scatter plot

# %%
sns.pairplot(df1, hue="Class variable", diag_kind = 'hist');

# %% [markdown]
# # Data Corelation

# %%
df1.corr()
# Out:
#                                                     Number of times pregnant  \
# Number of times pregnant                                            1.000000
# Plasma glucose concentration a 2 hours in an or...                  0.134915
# Diastolic blood pressure (mm Hg)                                    0.209668
# Triceps skin fold thickness (mm)                                    0.026697
# 2-Hour serum insulin (mu U/ml)                                     -0.048658
# Body mass index (weight in kg/(height in m)^2)                      0.012342
# Diabetes pedigree function                                         -0.025996
# Age (years)                                                         0.557066
# Class variable                                                      0.224417
#
#                                                     Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# Number of times pregnant                                                                     0.134915
# Plasma glucose concentration a 2 hours in an or...                                           1.000000
# Diastolic blood pressure (mm Hg)                                                             0.223331
# Triceps skin fold thickness (mm)                                                             0.173975
# 2-Hour serum insulin (mu U/ml)                                                               0.378975
# Body mass index (weight in kg/(height in m)^2)                                               0.223276
# Diabetes pedigree function                                                                   0.136630
# Age (years)                                                                                  0.263560
# Class variable                                                                               0.488384
#
#                                                     Diastolic blood pressure (mm Hg)  \
# Number of times pregnant                                                    0.209668
# Plasma glucose concentration a 2 hours in an or...                          0.223331
# Diastolic blood pressure (mm Hg)                                            1.000000
# Triceps skin fold thickness (mm)                                            0.149489
# 2-Hour serum insulin (mu U/ml)                                             -0.017832
# Body mass index (weight in kg/(height in m)^2)                              0.287403
# Diabetes pedigree function                                                 -0.000075
# Age (years)                                                                 0.324897
# Class variable                                                              0.166703
#
#                                                     Triceps skin fold thickness (mm)  \
# Number of times pregnant                                                    0.026697
# Plasma glucose concentration a 2 hours in an or...                          0.173975
# Diastolic blood pressure (mm Hg)                                            0.149489
# Triceps skin fold thickness (mm)                                            1.000000
# 2-Hour serum insulin (mu U/ml)                                              0.224331
# Body mass index (weight in kg/(height in m)^2)                              0.560071
# Diabetes pedigree function                                                  0.141855
# Age (years)                                                                 0.049803
# Class variable                                                              0.196026
#
#                                                     2-Hour serum insulin (mu U/ml)  \
# Number of times pregnant                                                 -0.048658
# Plasma glucose concentration a 2 hours in an or...                        0.378975
# Diastolic blood pressure (mm Hg)                                         -0.017832
# Triceps skin fold thickness (mm)                                          0.224331
# 2-Hour serum insulin (mu U/ml)                                            1.000000
# Body mass index (weight in kg/(height in m)^2)                            0.195858
# Diabetes pedigree function                                                0.171353
# Age (years)                                                              -0.002755
# Class variable                                                            0.172373
#
#                                                     Body mass index (weight in kg/(height in m)^2)  \
# Number of times pregnant                                                                  0.012342
# Plasma glucose concentration a 2 hours in an or...                                        0.223276
# Diastolic blood pressure (mm Hg)                                                          0.287403
# Triceps skin fold thickness (mm)                                                          0.560071
# 2-Hour serum insulin (mu U/ml)                                                            0.195858
# Body mass index (weight in kg/(height in m)^2)                                            1.000000
# Diabetes pedigree function                                                                0.154858
# Age (years)                                                                               0.020835
# Class variable                                                                            0.299375
#
#                                                     Diabetes pedigree function  \
# Number of times pregnant                                             -0.025996
# Plasma glucose concentration a 2 hours in an or...                    0.136630
# Diastolic blood pressure (mm Hg)                                     -0.000075
# Triceps skin fold thickness (mm)                                      0.141855
# 2-Hour serum insulin (mu U/ml)                                        0.171353
# Body mass index (weight in kg/(height in m)^2)                        0.154858
# Diabetes pedigree function                                            1.000000
# Age (years)                                                           0.023098
# Class variable                                                        0.184947
#
#                                                     Age (years)  \
# Number of times pregnant                               0.557066
# Plasma glucose concentration a 2 hours in an or...     0.263560
# Diastolic blood pressure (mm Hg)                       0.324897
# Triceps skin fold thickness (mm)                       0.049803
# 2-Hour serum insulin (mu U/ml)                        -0.002755
# Body mass index (weight in kg/(height in m)^2)         0.020835
# Diabetes pedigree function                             0.023098
# Age (years)                                            1.000000
# Class variable                                         0.245741
#
#                                                     Class variable
# Number of times pregnant                                  0.224417
# Plasma glucose concentration a 2 hours in an or...        0.488384
# Diastolic blood pressure (mm Hg)                          0.166703
# Triceps skin fold thickness (mm)                          0.196026
# 2-Hour serum insulin (mu U/ml)                            0.172373
# Body mass index (weight in kg/(height in m)^2)            0.299375
# Diabetes pedigree function                                0.184947
# Age (years)                                               0.245741
# Class variable                                            1.000000

# %% [markdown]
# # Data Ranking against Class Variable

# %% [markdown]
# <p style="color:red; text-align:center; font-size: 22px">Amar work - We need to fix sorting issue of Class variable.</p>

# %%
df2 = df1.corr()
df2['Class variable'].rank(method='dense',axis=0,ascending=False)
# Out:
# Number of times pregnant                                                    5.0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    2.0
# Diastolic blood pressure (mm Hg)                                            9.0
# Triceps skin fold thickness (mm)                                            6.0
# 2-Hour serum insulin (mu U/ml)                                              8.0
# Body mass index (weight in kg/(height in m)^2)                              3.0
# Diabetes pedigree function                                                  7.0
# Age (years)                                                                 4.0
# Class variable                                                              1.0
# Name: Class variable, dtype: float64

# %% [markdown]
# # Heatmap

# %%
cmatrix=df1.corr() 
plt.figure(figsize=(10,8),dpi=100)
sns.heatmap(cmatrix,annot=True,cmap='RdYlGn_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Covariance

# %%
df1.cov()
# Out:
#                                                     Number of times pregnant  \
# Number of times pregnant                                           11.308443
# Plasma glucose concentration a 2 hours in an or...                 13.951054
# Diastolic blood pressure (mm Hg)                                    8.728705
# Triceps skin fold thickness (mm)                                    0.845994
# 2-Hour serum insulin (mu U/ml)                                    -16.799397
# Body mass index (weight in kg/(height in m)^2)                      0.285908
# Diabetes pedigree function                                         -0.029051
# Age (years)                                                        22.040153
# Class variable                                                      0.358728
#
#                                                     Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# Number of times pregnant                                                                    13.951054
# Plasma glucose concentration a 2 hours in an or...                                         945.564344
# Diastolic blood pressure (mm Hg)                                                            85.018046
# Triceps skin fold thickness (mm)                                                            50.412364
# 2-Hour serum insulin (mu U/ml)                                                            1196.452240
# Body mass index (weight in kg/(height in m)^2)                                              47.297795
# Diabetes pedigree function                                                                   1.396177
# Age (years)                                                                                 95.352449
# Class variable                                                                               7.138635
#
#                                                     Diastolic blood pressure (mm Hg)  \
# Number of times pregnant                                                    8.728705
# Plasma glucose concentration a 2 hours in an or...                         85.018046
# Diastolic blood pressure (mm Hg)                                          153.261189
# Triceps skin fold thickness (mm)                                           17.439257
# 2-Hour serum insulin (mu U/ml)                                            -22.664733
# Body mass index (weight in kg/(height in m)^2)                             24.510973
# Diabetes pedigree function                                                 -0.000310
# Age (years)                                                                47.322627
# Class variable                                                              0.980999
#
#                                                     Triceps skin fold thickness (mm)  \
# Number of times pregnant                                                    0.845994
# Plasma glucose concentration a 2 hours in an or...                         50.412364
# Diastolic blood pressure (mm Hg)                                           17.439257
# Triceps skin fold thickness (mm)                                           88.798994
# 2-Hour serum insulin (mu U/ml)                                            217.036416
# Body mass index (weight in kg/(height in m)^2)                             36.357979
# Diabetes pedigree function                                                  0.444222
# Age (years)                                                                 5.521610
# Class variable                                                              0.878061
#
#                                                     2-Hour serum insulin (mu U/ml)  \
# Number of times pregnant                                                -16.799397
# Plasma glucose concentration a 2 hours in an or...                     1196.452240
# Diastolic blood pressure (mm Hg)                                        -22.664733
# Triceps skin fold thickness (mm)                                        217.036416
# 2-Hour serum insulin (mu U/ml)                                        10540.930813
# Body mass index (weight in kg/(height in m)^2)                          138.526461
# Diabetes pedigree function                                                5.846311
# Age (years)                                                              -3.328359
# Class variable                                                            8.412343
#
#                                                     Body mass index (weight in kg/(height in m)^2)  \
# Number of times pregnant                                                                  0.285908
# Plasma glucose concentration a 2 hours in an or...                                       47.297795
# Diastolic blood pressure (mm Hg)                                                         24.510973
# Triceps skin fold thickness (mm)                                                         36.357979
# 2-Hour serum insulin (mu U/ml)                                                          138.526461
# Body mass index (weight in kg/(height in m)^2)                                           47.457507
# Diabetes pedigree function                                                                0.354517
# Age (years)                                                                               1.688727
# Class variable                                                                            0.980339
#
#                                                     Diabetes pedigree function  \
# Number of times pregnant                                             -0.029051
# Plasma glucose concentration a 2 hours in an or...                    1.396177
# Diastolic blood pressure (mm Hg)                                     -0.000310
# Triceps skin fold thickness (mm)                                      0.444222
# 2-Hour serum insulin (mu U/ml)                                        5.846311
# Body mass index (weight in kg/(height in m)^2)                        0.354517
# Diabetes pedigree function                                            0.110433
# Age (years)                                                           0.090309
# Class variable                                                        0.029215
#
#                                                     Age (years)  \
# Number of times pregnant                              22.040153
# Plasma glucose concentration a 2 hours in an or...    95.352449
# Diastolic blood pressure (mm Hg)                      47.322627
# Triceps skin fold thickness (mm)                       5.521610
# 2-Hour serum insulin (mu U/ml)                        -3.328359
# Body mass index (weight in kg/(height in m)^2)         1.688727
# Diabetes pedigree function                             0.090309
# Age (years)                                          138.424467
# Class variable                                         1.374334
#
#                                                     Class variable
# Number of times pregnant                                  0.358728
# Plasma glucose concentration a 2 hours in an or...        7.138635
# Diastolic blood pressure (mm Hg)                          0.980999
# Triceps skin fold thickness (mm)                          0.878061
# 2-Hour serum insulin (mu U/ml)                            8.412343
# Body mass index (weight in kg/(height in m)^2)            0.980339
# Diabetes pedigree function                                0.029215
# Age (years)                                               1.374334
# Class variable                                            0.225952

# %%
plt.figure(figsize=(10,9))
plt.hist2d(df1["Plasma glucose concentration a 2 hours in an oral glucose tolerance test"], df1["Body mass index (weight in kg/(height in m)^2)"], bins=(20,20), cmap="magma")
plt.xlabel("Plasma glucose concentration a 2 hours in an oral glucose tolerance test")
plt.ylabel("Body mass index (weight in kg/(height in m)^2)")
plt.colorbar();

# %% [markdown]
# # Pair plot for significant influencers for outcome

# %%
sns.pairplot(df1[['Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
                  'Body mass index (weight in kg/(height in m)^2)',
                 'Age (years)', 'Number of times pregnant','Class variable']], kind='reg', hue='Class variable', diag_kind = 'hist');

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Tangerine">
# <div style="font-family: 'Tangerine', serif; text-align:center; font-size: 35px; text-shadow: 4px 4px 4px #aaa;">Conslusion</div>

# %%
sns.lmplot(data=df1,x='Plasma glucose concentration a 2 hours in an oral glucose tolerance test',y='Body mass index (weight in kg/(height in m)^2)',hue='Class variable')

# %%
sns.lmplot(data=df1,x='Plasma glucose concentration a 2 hours in an oral glucose tolerance test',y='Age (years)',hue='Class variable')

# %%
sns.lmplot(data=df1,x='Age (years)',y='Number of times pregnant',hue='Class variable')
