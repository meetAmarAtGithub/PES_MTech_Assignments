# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Tangerine">
# <div style="font-family: 'Tangerine', serif; text-align:center; font-size: 35px; text-shadow: 4px 4px 4px #aaa;"> A Visual Exploration and Analysis <br/><br/>of Diabetes Dataset</div>

# %% [markdown]
# ##  Table of Content
#
# 1. **[Overview ](#Overview)**<br/><br/>
# 2. **[Data Description ](#DataDescription)**<br/><br/>
# 3. **[Data Cleaning](#DataCleaning)**<br/><br/>
# 4. **[Data Exploration](#DataExploration)**<br/><br/>
# 5. **[Data Visualization & Analysis](#DataVisualizationAnalysis)**<br/><br/>
# 5. **[Conclusion](#Conclusion)**<br/><br/>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="Overview">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;">1. Overview</div>
# <br/></a>

# %% [markdown]
# The dataset has a total of <b> 768 rows </b> each referring to patients characterized by <b> 9 numeric variables </b>. The data refers to females of ages from 21 to 81 years. The nine attributes can be further classified as
#
# A)	Six attributes describe the result of physical / verbal examination<br/>
#     &emsp;
#     1)	Number of times pregnant<br/>
#     &emsp;
#     2)	Diastolic blood pressure (mm Hg)<br/>
#     &emsp;
#     3)	Triceps skin fold thickness (mm)<br/>
#     &emsp;
#     4)	Body mass index (weight in kg/(height in m)2)<br/>
#     &emsp;
#     5)	Diabetes pedigree function - a function which scores probability of getting diabetes based on family history<br/>
#     &emsp;
#     6)	Age (years)<br/><br/>
#
#    B)	Two attributes are result of chemical examination<br/>
#    &emsp;
#     7)	Plasma glucose concentration over 2 hours in an oral glucose tolerance test<br/>
#     &emsp;
#     8)	2-Hour serum insulin (mu U/ml)<br/><br/>
#
#    C)	Resultant Target Variable<br/>
#    &emsp;
#     9)	Class variable -0 (No) if non-diabetic, 1 (Yes) if diabetic<br/><br/>

# %% [markdown]
# <div style="font-family: 'Roboto', serif; font-size: 20px">Objective:</div> of this data analysis is to find the significant factors in the first 8 variables which influence the 9th variable that is if (Resultant)(diabetes=yes (1) diabetes = no (0)) through data analysis and visualization techniques using Python<br/><br/>

# %% [markdown]
# Diabetic Dataset and Jupyter program is hosted in <b> Github </b> to enable concurrent and collabrative working within the team

# %% [markdown]
# <div><img src="https://raw.githubusercontent.com/meetAmarAtGithub/PES_MTech_Assignments/master/NPV_Statitical%20Anlysis%20of%20Diabetes%20Dataset/pics/Team.JPG"></div>

# %% [markdown]
# <hr style=\"border:2px solid gray\"> </hr>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="DataDescription">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;"><br/><br/> 2. Data Description</div>
# <br/><br/></a>

# %%
#importing libraries for analyzing our data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from IPython.display import Image

# %% [markdown]
# ## Loading data and viewing first five rows

# %%
# dataset is hosted at Github following path - https://raw.githubusercontent.com/meetAmarAtGithub/PES_MTech_Assignments/master/NPV_Statitical%20Anlysis%20of%20Diabetes%20Dataset/diabetes.csv
df1 = pd.read_csv('https://raw.githubusercontent.com/meetAmarAtGithub/PES_MTech_Assignments/master/NPV_Statitical%20Anlysis%20of%20Diabetes%20Dataset/diabetes.csv')
df1.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  768 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          768 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            768 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            768 non-null    float64
# ...

# %% [markdown]
# ### Check for NAN in DataFrame

# %%
df1.isna().sum()
# Out:
# Number of times pregnant                                                    0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    0
# Diastolic blood pressure (mm Hg)                                            0
# Triceps skin fold thickness (mm)                                            0
# 2-Hour serum insulin (mu U/ml)                                              0
# Body mass index (weight in kg/(height in m)^2)                              0
# Diabetes pedigree function                                                  0
# Age (years)                                                                 0
# Class variable                                                              0
# dtype: int64

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>There is no NaN in dataframe.

# %% [markdown]
# ### Check for duplicate rows in Dataframe

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = df1[df1.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [Number of times pregnant, Plasma glucose concentration a 2 hours in an oral glucose tolerance test, Diastolic blood pressure (mm Hg), Triceps skin fold thickness (mm), 2-Hour serum insulin (mu U/ml), Body mass index (weight in kg/(height in m)^2), Diabetes pedigree function, Age (years), Class variable]
# Index: []

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>There are no duplicate rows <br>
# <hr style=\"border:2px solid gray\"> </hr>

# %% [markdown]
# ### Checking for count of zeroes for each column

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="DataCleaning">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;"><br/><br/>3. DataCleaning</div>
# <br/><br/></a>

# %% [markdown]
# ### Generate descriptive statistics

# %%
round(df1.describe(),2)
# Out:
#        Number of times pregnant  \
# count                    768.00
# mean                       3.85
# std                        3.37
# min                        0.00
# 25%                        1.00
# 50%                        3.00
# 75%                        6.00
# max                       17.00
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                             768.00
# mean                                              120.89
# std                                                31.97
# min                                                 0.00
# 25%                                                99.00
# 50%                                               117.00
# 75%                                               140.25
# max                                               199.00
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %% [markdown]
# #### Check for abnormality in minimum value being zero's

# %%
round(df1.describe().min(),2)
# Out:
# Number of times pregnant                                                     0.00
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test     0.00
# Diastolic blood pressure (mm Hg)                                             0.00
# Triceps skin fold thickness (mm)                                             0.00
# 2-Hour serum insulin (mu U/ml)                                               0.00
# Body mass index (weight in kg/(height in m)^2)                               0.00
# Diabetes pedigree function                                                   0.08
# Age (years)                                                                 11.76
# Class variable                                                               0.00
# dtype: float64

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>
# Minimum values for many variables are 0.<br>
# As biological parameters like Glucose, BP, Skin thickness,Insulin & BMI cannot have zero values, looks like null values have been coded as zeros <br>
# As a next step, find out how many Zero values are included in each variable<br>
# <hr style=\"border:.2px solid gray\"> </hr>

# %% [markdown]
# #### Checking for count of zeroes for each column

# %%
#This is to find how many column wise zero(0) rows are there!
print(df1.isin([0]).sum())
# Out:
# Number of times pregnant                                                    111
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test      5
# Diastolic blood pressure (mm Hg)                                             35
# Triceps skin fold thickness (mm)                                            227
# 2-Hour serum insulin (mu U/ml)                                              374
# Body mass index (weight in kg/(height in m)^2)                               11
# Diabetes pedigree function                                                    0
# Age (years)                                                                   0
# Class variable                                                              500
# dtype: int64

# %%
Image('./pics/Data_Validation.JPG')

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>
# Preganancy and Result can have zero values hence ignored <br>
# As Zero count of Glucose (5) , Blood Pressure (35) and BMI (11) are low it is recommended to remove the Zeros uniformly for these 3 variables <br>
# As Zero Counts of Insulin (374)  and Skin Thicknesss 227, in a 768 data set need to be investigated to prevent ~ 50% sample size reduction <br>
# As a next step, suitablity of Mean or Median replacement will be investigated
# <hr style=\"border:2px solid gray\"> </hr>

# %% [markdown]
# #### Finding the optimial values to replace in skin thickness and insulin levels to replace zero values

# %%
# create a temporary dataframe removing zero values to avoid skew in mean and median
df2 = df1[df1['2-Hour serum insulin (mu U/ml)'] > 0]
print(df2.isin([0]).sum())
# Out:
# Number of times pregnant                                                     57
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test      1
# Diastolic blood pressure (mm Hg)                                              0
# Triceps skin fold thickness (mm)                                              0
# 2-Hour serum insulin (mu U/ml)                                                0
# Body mass index (weight in kg/(height in m)^2)                                1
# Diabetes pedigree function                                                    0
# Age (years)                                                                   0
# Class variable                                                              264
# dtype: int64

# %%
# find the grouped mean and median of insulin level
grouped_df =df2.groupby('Class variable')
smean = round(grouped_df['2-Hour serum insulin (mu U/ml)'].mean(),2)
smedian =round(grouped_df['2-Hour serum insulin (mu U/ml)'].median(),2)
smean
smedian
# Out:
# Class variable
# 0    102.5
# 1    169.5
# Name: 2-Hour serum insulin (mu U/ml), dtype: float64

# %%
df2.head()
# Out:
#     Number of times pregnant  \
# 3                          1
# 4                          0
# 6                          3
# 8                          2
# 13                         1
#
#     Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 3                                                  89
# 4                                                 137
# 6                                                  78
# 8                                                 197
# 13                                                189
#
#     Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 3                                 66                                23
# 4                                 40                                35
# 6                                 50                                32
# 8                                 70                                45
# 13                                60                                23
#
# ...

# %%
# find the grouped mean and median of insulin level\n",
grouped_df =df2.groupby('Class variable')
smean = round(grouped_df['2-Hour serum insulin (mu U/ml)'].mean(),2)
smedian =round(grouped_df['2-Hour serum insulin (mu U/ml)'].median(),2)

# %%
sns.boxplot(y='2-Hour serum insulin (mu U/ml)', x='Class variable', 
                 data=df2, 
                 palette="colorblind",
                 hue='Class variable',showmeans=True,
           meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.text(0,smean.loc[0],str((smean.loc[0])))
plt.text(1*.75,smean.loc[1],str((smean.loc[1])))
plt.text(0,smedian.loc[0],str((smedian.loc[0])))
plt.text(1*.75,smedian.loc[1],str((smedian.loc[1])))
# Out:
# Text(0.75, 169.5, '169.5')

# %% [markdown]
# <p class=MsoNormal><span class=GramE><b style='mso-bidi-font-weight:normal'><span
# style='font-size:14.0pt;line-height:107%;font-family:"Helvetica",sans-serif;
# color:#4472C4;mso-themecolor:accent1;background:white'>Observation for insulin level data :</span></b></span><b
# style='mso-bidi-font-weight:normal'><span style='font-size:14.0pt;line-height:
# 107%;font-family:"Helvetica",sans-serif;color:#4472C4;mso-themecolor:accent1;
# background:white'><o:p></o:p></span></b></p>
#
# <p class=MsoNormal><span style='font-size:10.5pt;line-height:107%;font-family:
# "Helvetica",sans-serif;color:black;background:white'><span
# style='mso-spacerun:yes'> </span>Outliers are observed, hence its preferred to
# use Median value for replacement of zeros. There is also significant difference
# in medians of diabetic and non-diabetic hence team decided to replace insulin
# level zero’s with <o:p></o:p></span></p>
#
# <p class=MsoNormal><b style='mso-bidi-font-weight:normal'><span
# style='font-size:10.5pt;line-height:107%;font-family:"Helvetica",sans-serif;
# color:black;background:white'>Non-Diabetic --&gt; 102.5<o:p></o:p></span></b></p>
#
# <p class=MsoNormal><b style='mso-bidi-font-weight:normal'><span
# style='font-size:10.5pt;line-height:107%;font-family:"Helvetica",sans-serif;
# color:black;background:white'><span style='mso-spacerun:yes'> </span>Diabetic
# --&gt; 169.5</span></span><o:p></o:p></b></p>

# %%
# find the grouped mean and median of skin fold thickness

smean = round(grouped_df['Triceps skin fold thickness (mm)'].mean(),2)
smedian =round(grouped_df['Triceps skin fold thickness (mm)'].median(),2)

# %%
sns.boxplot(y='Triceps skin fold thickness (mm)', x='Class variable', 
                 data=df2, 
                 palette="colorblind",
                 hue='Class variable',showmeans=True,
           meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.text(0,smean.loc[0],str((smean.loc[0])))
plt.text(1*.75,smean.loc[1],str((smean.loc[1])))
#plt.text(0,smedian.loc[0],str((smedian.loc[0])))
#plt.text(1*.75,smedian.loc[1],str((smedian.loc[1])))
# Out:
# Text(0.75, 32.96, '32.96')

# %% [markdown]
# <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
# normal;background:white'><b><span style='font-size:14.0pt;font-family:"Helvetica",sans-serif;
# mso-fareast-font-family:"Times New Roman";color:#4472C4;background:white'>Observation
# for skin thickness <span class=GramE>data :</span></span></b><span
# style='font-size:10.5pt;font-family:"Helvetica",sans-serif;mso-fareast-font-family:
# "Times New Roman";color:black'><o:p></o:p></span></p>
#
# <p class=MsoNormal style='margin-top:12.0pt;margin-right:0in;margin-bottom:
# 0in;margin-left:0in;margin-bottom:.0001pt;line-height:normal;background:white'><span
# style='font-size:10.5pt;font-family:"Helvetica",sans-serif;mso-fareast-font-family:
# "Times New Roman";color:black;background:white;mso-bidi-font-weight:bold'>There
# is no significant difference between the mean and <span class=GramE>median ,</span>
# hence zero values to be replaced with the corresponding mean values of diabetic
# and non-diabetic<o:p></o:p></span></p>
#
# <p class=MsoNormal style='margin-top:12.0pt;margin-right:0in;margin-bottom:
# 0in;margin-left:0in;margin-bottom:.0001pt;line-height:normal;background:white'><span
# style='font-size:10.5pt;font-family:"Helvetica",sans-serif;mso-fareast-font-family:
# "Times New Roman";color:black;background:white;mso-bidi-font-weight:bold'><o:p>&nbsp;</o:p></span></p>
#
# <table class=MsoTableGrid border=1 cellspacing=0 cellpadding=0
#  style='border-collapse:collapse;border:none;mso-border-alt:solid windowtext .5pt;
#  mso-yfti-tbllook:1184;mso-padding-alt:0in 5.4pt 0in 5.4pt'>
#  <tr style='mso-yfti-irow:0;mso-yfti-firstrow:yes'>
#   <td width=126 valign=top style='width:94.25pt;border:solid windowtext 1.0pt;
#   mso-border-alt:solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'><b style='mso-bidi-font-weight:normal'>Group<o:p></o:p></b></p>
#   </td>
#   <td width=90 valign=top style='width:67.5pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-left-alt:solid windowtext .5pt;mso-border-alt:
#   solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b style='mso-bidi-font-weight:normal'>Mean<o:p></o:p></b></p>
#   </td>
#   <td width=84 valign=top style='width:63.0pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-left-alt:solid windowtext .5pt;mso-border-alt:
#   solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal'><b style='mso-bidi-font-weight:normal'>Median<o:p></o:p></b></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:1'>
#   <td width=126 valign=top style='width:94.25pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-top-alt:solid windowtext .5pt;mso-border-alt:solid windowtext .5pt;
#   padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'>Non-Diabetic</p>
#   </td>
#   <td width=90 valign=top style='width:67.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-top-alt:solid windowtext .5pt;mso-border-left-alt:solid windowtext .5pt;
#   mso-border-alt:solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal align=center style='margin-bottom:0in;margin-bottom:.0001pt;
#   text-align:center;line-height:normal;tab-stops:45.8pt 91.6pt 137.4pt 183.2pt 229.0pt 274.8pt 320.6pt 366.4pt 412.2pt 458.0pt 503.8pt 549.6pt 595.4pt 641.2pt 687.0pt 732.8pt;
#   background:white;vertical-align:baseline;word-break:break-all'><span
#   style='font-size:10.5pt;font-family:"Courier New";mso-fareast-font-family:
#   "Times New Roman";color:black'>27.21<o:p></o:p></span></p>
#   </td>
#   <td width=84 valign=top style='width:63.0pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-top-alt:solid windowtext .5pt;mso-border-left-alt:solid windowtext .5pt;
#   mso-border-alt:solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'><pre
#   style='text-align:center;background:white;vertical-align:baseline;word-break:
#   break-all'><span style='font-size:10.5pt;color:black'>27<o:p></o:p></span></pre></td>
#  </tr>
#  <tr style='mso-yfti-irow:2;mso-yfti-lastrow:yes'>
#   <td width=126 valign=top style='width:94.25pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-top-alt:solid windowtext .5pt;mso-border-alt:solid windowtext .5pt;
#   padding:0in 5.4pt 0in 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0in;margin-bottom:.0001pt;line-height:
#   normal'>Diabetic</p>
#   </td>
#   <td width=90 valign=top style='width:67.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-top-alt:solid windowtext .5pt;mso-border-left-alt:solid windowtext .5pt;
#   mso-border-alt:solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'><pre
#   style='text-align:center;background:white;vertical-align:baseline;word-break:
#   break-all'><span style='font-size:10.5pt;color:black'>32.96<o:p></o:p></span></pre></td>
#   <td width=84 valign=top style='width:63.0pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-top-alt:solid windowtext .5pt;mso-border-left-alt:solid windowtext .5pt;
#   mso-border-alt:solid windowtext .5pt;padding:0in 5.4pt 0in 5.4pt'><pre
#   style='text-align:center;background:white;vertical-align:baseline;word-break:
#   break-all'><span style='font-size:10.5pt;color:black'>33<o:p></o:p></span></pre></td>
#  </tr>
# </table>
#
# <p class=MsoNormal><o:p>&nbsp;</o:p></p>

# %%
# copy Dataframe to clean container before mutating
df_clean =df1

# %% [markdown]
# #### Replace  rows with zero's in high sample population with suitable Mean / Median

# %%
# replace insulin level zero values
df_clean['2-Hour serum insulin (mu U/ml)'] = np.where(((df_clean['2-Hour serum insulin (mu U/ml)']==0)&(df_clean['Class variable']==0)), 102.5, df_clean['2-Hour serum insulin (mu U/ml)'])
df_clean['2-Hour serum insulin (mu U/ml)'] = np.where(((df_clean['2-Hour serum insulin (mu U/ml)']==0)&(df_clean['Class variable']==1)), 169.5, df_clean['2-Hour serum insulin (mu U/ml)'])

# %%
# replace skin thickness zeros
df_clean['Triceps skin fold thickness (mm)'] = np.where(((df_clean['Triceps skin fold thickness (mm)']==0)&(df_clean['Class variable']==0)), 27.21, df_clean['Triceps skin fold thickness (mm)'])
df_clean['Triceps skin fold thickness (mm)'] = np.where(((df_clean['Triceps skin fold thickness (mm)']==0)&(df_clean['Class variable']==1)), 32.96, df_clean['Triceps skin fold thickness (mm)'])

# %% [markdown]
# #### Drop rows with zero's with low sample population

# %%
# drop zero values in plasma glucose
df_clean =df_clean[df_clean['Plasma glucose concentration a 2 hours in an oral glucose tolerance test'] > 0]
## df1.info()

# %%
# drop zero values in blood pressure
df_clean =df_clean[df_clean['Diastolic blood pressure (mm Hg)'] > 0]
##df1.info()

# %%
# drop zero values in BMI
df_clean =df_clean[df_clean['Body mass index (weight in kg/(height in m)^2)'] > 0]
##df1.info()

# %% [markdown]
# #### Rename long column names with alias to improve graph readablity

# %%
df_clean.rename(columns={'Number of times pregnant':'No_Times_Pregnant',
                    'Plasma glucose concentration a 2 hours in an oral glucose tolerance test':'Plasma_Glucose',
                   'Diastolic blood pressure (mm Hg)':'Blood_Pressure',
                   'Triceps skin fold thickness (mm)':'Tricep_Skin_Thickness',
                   '2-Hour serum insulin (mu U/ml)':'Serum_Insulin',
                   'Body mass index (weight in kg/(height in m)^2)':'BMI',
                   'Diabetes pedigree function':'Pedigree',
                   'Age (years)':'Age',
                   'Class variable':'Results'},inplace=True)
df_clean.head()
# Out:
#    No_Times_Pregnant  Plasma_Glucose  Blood_Pressure  Tricep_Skin_Thickness  \
# 0                  6             148              72                  35.00
# 1                  1              85              66                  29.00
# 2                  8             183              64                  32.96
# 3                  1              89              66                  23.00
# 4                  0             137              40                  35.00
#
#    Serum_Insulin   BMI  Pedigree  Age  Results
# 0          169.5  33.6     0.627   50        1
# 1          102.5  26.6     0.351   31        0
# 2          169.5  23.3     0.672   32        1
# 3           94.0  28.1     0.167   21        0
# 4          168.0  43.1     2.288   33        1

# %% [markdown]
# #### Check to see if all zero's have been mutated

# %%
#This is to find how many column wise zero(0) rows are there!
print(df_clean.isin([0]).sum())
# Out:
# No_Times_Pregnant         99
# Plasma_Glucose             0
# Blood_Pressure             0
# Tricep_Skin_Thickness      0
# Serum_Insulin              0
# BMI                        0
# Pedigree                   0
# Age                        0
# Results                  475
# dtype: int64

# %% [markdown]
# #### Data Frame Cleaning Completed
# <hr style=\"border:2px solid gray\"> </hr>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="DataExploration">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;"><br/><br/>4. Data Exploration</div>
# <br/><br/></a>

# %% [markdown]
# #### Univariate Analysis

# %%
vc =df_clean.Results.value_counts()
plt.figure(figsize =(5,4),dpi =100)
plt.pie(x=vc,autopct ='%.2f' ,labels=['Non-Diabetic','Diabetic'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(4,2, figsize=(16,16))
sns.histplot(df_clean.No_Times_Pregnant, bins = 20, ax=ax[0,0],kde=True)
sns.histplot(df_clean.Plasma_Glucose, bins = 20, ax=ax[0,1],kde=True)
sns.histplot(df_clean.Blood_Pressure, bins = 20, ax=ax[1,0],kde=True)
sns.histplot(df_clean.Tricep_Skin_Thickness, bins = 20, ax=ax[1,1],kde=True)
sns.histplot(df_clean.Serum_Insulin, bins = 20, ax=ax[2,0],kde=True)
sns.histplot(df_clean.BMI, bins = 20, ax=ax[2,1],kde=True)
sns.histplot(df_clean.Pedigree, bins = 20, ax=ax[3,0],kde=True)
sns.histplot(df_clean.Age, bins = 20, ax=ax[3,1],kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Bi Variate Analysis

# %% [markdown]
# #### Pair plot to compare inter relation between variables

# %%
sns.pairplot(df_clean, hue="Results", diag_kind = 'kde')

# %%
fig,ax = plt.subplots(nrows=4, ncols=2, figsize=(18,18))
    
plt.suptitle('Violin and Box Plots',fontsize=24)
sns.violinplot(y="No_Times_Pregnant",x ='Results',data=df_clean,ax=ax[0,0],inner="box",palette='Set3', linewidth=1,hue=df_clean.Results)
sns.boxplot(y="Plasma_Glucose",x = 'Results', data=df_clean,ax=ax[0,1],palette='Set3',hue =df_clean.Results)
sns.violinplot (y ='Blood_Pressure',x = 'Results', data=df_clean, ax=ax[1,0], palette='Set3',hue =df_clean.Results)
sns.boxplot(y='Tricep_Skin_Thickness',x = 'Results', data=df_clean, ax=ax[1,1],palette='Set3')
sns.violinplot(y='Serum_Insulin',x = 'Results', data=df_clean, ax=ax[2,0], palette='Set3')
sns.boxplot(y='BMI',x = 'Results', data=df_clean, ax=ax[2,1],palette='Set3')
sns.violinplot(y='Pedigree',x = 'Results', data=df_clean, ax=ax[3,0],palette='Set3')
sns.boxplot(y='Age', x = 'Results',data=df_clean, ax=ax[3,1],palette='Set3')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Age'>

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>From scatter plots, only BMI & SkinThickness and Pregnancies & Age seem to have positive linear relationships. Another likely suspect is Glucose and Insulin.<br>
# There are no non-linear relationships<br>
# Further investatigation to be done with Pearson Correlation and plot heat maps<br>
#     <hr style="border:.2px solid gray"> </hr>

# %% [markdown]
# # Data Corelation

# %%
round(df_clean.corr(),2)
# Out:
#                        No_Times_Pregnant  Plasma_Glucose  Blood_Pressure  \
# No_Times_Pregnant                   1.00            0.13            0.21
# Plasma_Glucose                      0.13            1.00            0.22
# Blood_Pressure                      0.21            0.22            1.00
# Tricep_Skin_Thickness               0.09            0.23            0.20
# Serum_Insulin                       0.05            0.49            0.07
# BMI                                 0.01            0.22            0.29
# Pedigree                           -0.03            0.14           -0.00
# Age                                 0.56            0.26            0.32
# Results                             0.22            0.49            0.17
#
#                        Tricep_Skin_Thickness  Serum_Insulin   BMI  Pedigree  \
# No_Times_Pregnant                       0.09           0.05  0.01     -0.03
# Plasma_Glucose                          0.23           0.49  0.22      0.14
# ...

# %% [markdown]
# # Heatmap

# %%
cmatrix=df_clean.corr() 
plt.figure(figsize=(10,8),dpi=100)
sns.heatmap(cmatrix,annot=True,cmap='RdYlGn_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Ranking against Result

# %%
df2 = df_clean.corr()
df2['Rank'] =df2['Results'].rank(method='dense',axis=0,ascending=False)
df2.sort_values(by ='Rank',ascending=True,inplace =True)
display(df2[['Results','Rank']])
# Out:
#                         Results  Rank
# Results                1.000000   1.0
# Plasma_Glucose         0.488384   2.0
# Serum_Insulin          0.369064   3.0
# BMI                    0.299375   4.0
# Tricep_Skin_Thickness  0.296808   5.0
# Age                    0.245741   6.0
# No_Times_Pregnant      0.224417   7.0
# Pedigree               0.184947   8.0
# Blood_Pressure         0.166703   9.0

# %% [markdown]
# <font color='blue'><b> Observation :</font> </b> <br>to be update<br>
#     <hr style="border:2px solid gray"> </hr>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="DataVisualizationAnalysis">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;"><br/><br/>5. Data Visualization & Analysis</div>
# <br/><br/></a>

# %%
sns.lmplot(data=df1,x='Plasma_Glucose',y='Serum_Insulin',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='BMI',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='Tricep_Skin_Thickness',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='Age',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='No_Times_Pregnant',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='Pedigree',hue='Results')

# %%
sns.lmplot(data=df1,y='Plasma_Glucose',x='Blood_Pressure',hue='Results')

# %%
x_col = 'Plasma_Glucose'
y_col = 'Age'
y_2_col = 'No_Times_Pregnant'
hue_col = 'Results'
sns.lmplot(data=df1,x=x_col,y=y_col, col=y_2_col, hue=hue_col, markers=["x", "o"]) 
# sns.lmplot(data=df1,x='Plasma_Glucose',y='BMI',hue='Results', ax=axs[1])

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto&display=swap">
# <a id="Conclusion">
# <div style="font-family: 'Roboto', serif; text-align:center; font-size: 40px; text-align:center;">6. Conclusion</div>
# <br/></a>

# %%
# check if this file is shown
